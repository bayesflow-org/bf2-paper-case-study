# %% [markdown]
# # Lotka-Volterra Dynamics

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

import bayesflow as bf

import keras
# Out:
# INFO:2025-11-17 10:00:27,339:jax._src.xla_bridge:822: Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': UNIMPLEMENTED: LoadPjrtPlugin is not implemented on windows yet.
# INFO:bayesflow:Using backend 'jax'

# %%
import sys
sys.path.append("../")

from helpers import plot_lv_trajectores, expert_stats

# %%
# avoid scientific notation for outputs
np.set_printoptions(suppress=True)

# %% [markdown]
# ## Ecology Simulator
#
# Suppose we measured population counts from two species over time. One of them preys on the other, so we might assume that the dynamics are governed by the classic Lotka-Volterra system.
#
# In dimensionless form, with prey population $x$ and predator population $y$, the nonlinear differential equation is
#
# $$
# \begin{aligned}{\frac {dx}{dt}}&=\alpha x-\beta xy,\\{\frac {dy}{dt}}&=-\gamma y+\delta xy.\end{aligned}
# $$
#
# As always, this model entails a number of assumptions that can only be approximate. In brief:
#
# - On their own, prey count increases exponentially with rate $\alpha$, while predator count decays with rate $\gamma$.
# - Interesting dynamics are possible when both predators and prey are present: The number of predators increases the more prey it can hunt, reducing prey counts proportionally at a rate $\beta$ and increasing predator count proportionally at a rate $\delta$.
# - We can measure population timeseries, but never the parameters directly, so this is a scientifically relevant inverse problem.
#
# The Lotka-Volterra equations alone are not yet a precise, falsifiable model, since they do not predict anything measureable. We must pick parameters, initial conditions, and an observation model which describes how (noisy) measurements take place. The wide applicability of simulation-based inference is due to the fact that **scientific hypotheses typically come in the form of simulators of measurable quantities**.
#
# Our simulator will consist of three parts:
# 1. First, we choose a prior distribution over parameters that reflects our beliefs about parameters before observing data.
# 2. Building on parameters sampled from the prior, we solve the parameterized Lotka-Volterra equation starting from some initial conditions.
# 3. Finally, we hypothesize that we will make some counting errors when observing the populations, introducing a Gaussian error on the true populations.

# %% [markdown]
# A random number generator with a fixed seed will ensure reproducibility of the simulated training and validation data.

# %%
rng = np.random.default_rng(seed=2025)

# %%
def prior():
    x = rng.normal(size=4)
    # logit normal distribution scaled to range from 0.1 and 4
    theta = 1/(1+np.exp(-x)) * 3.9 + 0.1 
    return dict(
        alpha=theta[0],
        beta=theta[1],
        gamma=theta[2],
        delta=theta[3],
    )


def lotka_volterra_equations(state, t, alpha, beta, gamma, delta):
    x, y = state
    dxdt = alpha * x - beta * x * y
    dydt = - gamma * y + delta * x * y
    return [dxdt, dydt]


def ecology_model(alpha, beta, gamma, delta, t_span=[0, 5], t_steps=100, initial_state=[1, 1]):
    t = np.linspace(t_span[0], t_span[1], t_steps)
    state = odeint(lotka_volterra_equations, initial_state, t, args=(alpha, beta, gamma, delta))
    x, y = state.T
    
    return dict(
        x=x,  # Prey time series
        y=y,  # Predator time series
        t=t,  # Time vector
    )


def observation_model(x, y, t, subsample=10, obs_prob=1.0, noise_scale=0.1):
    t_steps = x.shape[0]
    
    # Add Gaussian noise to observations
    noisy_x = rng.normal(x, noise_scale)
    noisy_y = rng.normal(y, noise_scale)
    
    # Determine which time steps are observed
    step_indices = np.arange(0, t_steps, subsample)
    num_observed = int(obs_prob * len(step_indices))
    observed_indices = np.sort(rng.choice(step_indices, num_observed, replace=False))

    return {
        "observed_x": noisy_x[observed_indices],
        "observed_y": noisy_y[observed_indices],
        "observed_t": t[observed_indices]
    }

# %%
p = prior()
p
# Out:
# {'alpha': 0.48164641056373625,
#  'beta': 2.075348233437099,
#  'gamma': 1.5368670432270386,
#  'delta': 1.052809398167223}

# %%
observation_model(**ecology_model(**p))
# Out:
# {'observed_x': array([0.75581334, 0.36169536, 0.56944328, 0.44004584, 0.44921465,
#         0.62785572, 0.36257802, 0.81612008, 0.88862044, 0.87738167]),
#  'observed_y': array([ 1.07164387,  0.5892121 ,  0.54888111,  0.29705669,  0.03348947,
#          0.14288611, -0.06268263,  0.15279859,  0.0750439 ,  0.19735671]),
#  'observed_t': array([0.        , 0.50505051, 1.01010101, 1.51515152, 2.02020202,
#         2.52525253, 3.03030303, 3.53535354, 4.04040404, 4.54545455])}

# %% [markdown]
# We can combine these three components into a BayesFlow simulator via:

# %%
simulator = bf.make_simulator(
    [prior, ecology_model, observation_model]
)

# %%
simulator.sample(2)["x"].shape
# Out:
# (2, 100)

# %% [markdown]
# Let's sample 100 trajectories, and see what we get:

# %%
num_trajectories = 80
samples = simulator.sample(num_trajectories)
keras.tree.map_structure(keras.ops.shape, samples)
# Out:
# {'alpha': (80, 1),
#  'beta': (80, 1),
#  'gamma': (80, 1),
#  'delta': (80, 1),
#  'x': (80, 100),
#  'y': (80, 100),
#  't': (80, 100),
#  'observed_x': (80, 10),
#  'observed_y': (80, 10),
#  'observed_t': (80, 10)}

# %% [markdown]
# What types of developments (and observations) does our Lotka-Volterra simulator predict? We should have a function to visualize sampled trajectories and take a look!

# %%
plot_lv_trajectores(samples, ["x", "y"], ["Prey", "Predator"], num_to_plot=80)

# %% [markdown]
# Above, we cen see how to access the *prior predictive distribution* of the simulator. The shaded area contains 95% of trajectories at each timestep, additionally we see a few example trajectories.
#
# Predator and prey populations generally oscillate in this model, but the frequency, amplitude, relative lag, and scale varies greatly for different parameters.
#
# The prior predictive distribution should match our expectation of the real world system of interest before we take into account concrete observed population counts.
# Here, we see the prior implies population magnitudes to oscillate (mostly) below 6.

# %% [markdown]
# ## Domain Expert Statistics
#
# Ultimately, we want to learn maximally informative summary statistics jointly with an amortized posterior approximation, but hand crafted summary statistics have the benefit of being interpretable and fast to compute. Oftentimes, there are a few natural and established statistics for a particular modality of raw data. Domain experts are likely to have made significant progress in finding closed form expressions or algorithms for informative summaries.
#
# Compared to the *sufficient summary statistics*, we can expect there to be less posterior contraction.
#
# Still, we can reasonably expect that oscillation period, mean, (log) variance, autocorrelation at different lags of both trajectories, and the cross correlation between the two trajectories are highly informative when taken together as summary statistics.

# %% [markdown]
# To compute the expert statistics we can append the `expert_stats` function to the `simulator` object.

# %%
simulator = bf.make_simulator([prior, ecology_model, observation_model, expert_stats])

# %%
samples_with_expert_stats = simulator.sample(3)

keras.tree.map_structure(keras.ops.shape, samples_with_expert_stats)
# Out:
# {'alpha': (3, 1),
#  'beta': (3, 1),
#  'gamma': (3, 1),
#  'delta': (3, 1),
#  'x': (3, 100),
#  'y': (3, 100),
#  't': (3, 100),
#  'observed_x': (3, 10),
#  'observed_y': (3, 10),
#  'observed_t': (3, 10),
#  'means': (3, 2),
#  'log_vars': (3, 2),
#  'auto_corrs': (3, 4),
#  'cross_corr': (3, 1),
#  'period': (3, 1)}

# %% [markdown]
# Let us now generate training and validation data for our amortized setup. Below, we will demonstrate *offline training* on a relatively small set of $B = 5000$ simulations.

# %%
training_data = simulator.sample(5000)
validation_data = simulator.sample(300)

# %% [markdown]
# ## Posterior Approximation with Hand-Crafted Summary Statistics

# %% [markdown]
# ### Inference Network
#
#
# Flow Matching is a technique for training neural ODEs (ordinary differential equations) to learn continuous-time dynamics that transform a simple base distribution (e.g., a Gaussian) into a target distribution (e.g., a posterior over simulator parameters). It can be seen as a reparameterization of score-based diffusion models.
#
# At its core, Flow Matching learns a velocity field $\mathbf{v}_\theta(\theta; y, t)$ such that trajectories starting from the base distribution transform into samples from the target distribution over a fixed time interval (typically $t \in [0, 1]$).

# %%
flow = bf.networks.CouplingFlow(depth=2, transform="spline")

# %% [markdown]
# ### Adapter
#
# To ensure that the training data generated by the simulator can be used for deep learning in the way you intend, you can apply any number of transformations via `adapter` objects. They provides multiple flexible functionalities, from standardization to renaming, and so on.
#
# BayesFlow provides default adapters that automate some of these steps, but for the purpose of this tutorial, we explicate the construction of the adapter. The only requirement for adapters is that the `inference_variables` key is present, indicating which variables are the inference targets.

# %%
par_names = [r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"]

adapter = (
    bf.adapters.Adapter()

    # convert from numpy's default float64 to deep learning friendly float32
    .convert_dtype("float64", "float32")

    # drop unobserved full trajectories and raw observations (optional)
    .drop(["x", "y", "t", "observed_x", "observed_y", "observed_t"])

    # rename the variables to match the required approximator inputs
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")
    .concatenate(["means", "log_vars", "auto_corrs", "cross_corr", "period"], into="inference_conditions")

)
adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't', 'observed_x', 'observed_y', 'observed_t']) -> 2: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 3: Concatenate(['means', 'log_vars', 'auto_corrs', 'cross_corr', 'period'] -> 'inference_conditions')])

# %% [markdown]
# ### Basic Workflow and Training

# %%
workflow = bf.BasicWorkflow(
    adapter=adapter,
    inference_network=flow,
)

# %%
epochs = 50
batch_size = 32

# %%
history = workflow.fit_offline(
    data=training_data, 
    epochs=epochs, 
    batch_size=batch_size, 
    validation_data=validation_data,
    checkpoint_filepath="test/"
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 8s 31ms/step - loss: -0.0342 - val_loss: -0.2112
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0234 - val_loss: -0.3899
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0669 - val_loss: -0.4283
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0280 - val_loss: -0.4525
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.0314 - val_loss: -0.4755
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: -0.0758 - val_loss: -0.5545
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.1455 - val_loss: -0.6397
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.1928 - val_loss: -0.4392
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.1996 - val_loss: -0.6305
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.2574 - val_loss: -0.7355
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.3204 - val_loss: -0.6553
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.3220 - val_loss: -0.7899
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: -0.3548 - val_loss: -0.6568
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.3946 - val_loss: -0.7566
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.4801 - val_loss: -0.7998
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: -0.4852 - val_loss: -0.9321
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: -0.4923 - val_loss: -0.8400
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.5044 - val_loss: -0.7604
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.5535 - val_loss: -0.9678
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: -0.6129 - val_loss: -0.9595
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: -0.6283 - val_loss: -0.9593
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.6392 - val_loss: -1.1157
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.6867 - val_loss: -1.1379
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.7013 - val_loss: -1.0277
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.7440 - val_loss: -1.1323
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.7833 - val_loss: -1.0753
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: -0.7764 - val_loss: -1.0290
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.8201 - val_loss: -1.2451
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: -0.8254 - val_loss: -1.2511
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: -0.8868 - val_loss: -1.2610
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: -0.8718 - val_loss: -1.2867
# Epoch 32/50
# 106/157 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: -0.9517CPU times: total: 1min 18s
# Wall time: 31.8 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'history = workflow.fit_offline(\n    data=training_data, \n    epochs=epochs, \n    batch_size=batch_size, \n    validation_data=validation_data,\n    checkpoint_filepath="test"\n)\n')
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\IPython\core\interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\IPython\core\magics\execution.py:1470, in ExecutionMagics.time(self, line, cell, local_ns)
#    1468 if interrupt_occured:
#    1469     if exit_on_interrupt and captured_exception:
# -> 1470         raise captured_exception
#    1471     return
#    1472 return out
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\IPython\core\magics\execution.py:1434, in ExecutionMagics.time(self, line, cell, local_ns)
#    1432 st = clock2()
#    1433 try:
# -> 1434     exec(code, glob, local_ns)
#    1435     out = None
#    1436     # multi-line %%time case
#
# File <timed exec>:1
#
# File ~\Desktop\Projects\BayesFlow\bayesflow\workflows\basic_workflow.py:737, in BasicWorkflow.fit_offline(self, data, epochs, batch_size, keep_optimizer, validation_data, augmentations, **kwargs)
#     692 """
#     693 Train the approximator offline using a fixed dataset. This approach will be faster than online training,
#     694 since no computation time is spent in generating new data for each batch, but it assumes that simulations
#    (...)    732     metric evolution over epochs.
#     733 """
#     735 dataset = OfflineDataset(data=data, batch_size=batch_size, adapter=self.adapter, augmentations=augmentations)
# --> 737 return self._fit(
#     738     dataset,
#     739     epochs,
#     740     strategy="offline",
#     741     keep_optimizer=keep_optimizer,
#     742     validation_data=validation_data,
#     743     **kwargs,
#     744 )
#
# File ~\Desktop\Projects\BayesFlow\bayesflow\workflows\basic_workflow.py:981, in BasicWorkflow._fit(self, dataset, epochs, strategy, keep_optimizer, validation_data, **kwargs)
#     978     self.approximator.compile(optimizer=self.optimizer, metrics=kwargs.pop("metrics", None))
#     980 try:
# --> 981     self.history = self.approximator.fit(
#     982         dataset=dataset, epochs=epochs, validation_data=validation_data, **kwargs
#     983     )
#     984     self._on_training_finished()
#     985     return self.history
#
# File ~\Desktop\Projects\BayesFlow\bayesflow\approximators\continuous_approximator.py:315, in ContinuousApproximator.fit(self, *args, **kwargs)
#     263 def fit(self, *args, **kwargs):
#     264     """
#     265     Trains the approximator on the provided dataset or on-demand data generated from the given simulator.
#     266     If `dataset` is not provided, a dataset is built from the `simulator`.
#    (...)    313         If both `dataset` and `simulator` are provided or neither is provided.
#     314     """
# --> 315     return super().fit(*args, **kwargs, adapter=self.adapter)
#
# File ~\Desktop\Projects\BayesFlow\bayesflow\approximators\approximator.py:139, in Approximator.fit(self, dataset, simulator, **kwargs)
#     136     mock_data_shapes = keras.tree.map_structure(keras.ops.shape, mock_data)
#     137     self.build(mock_data_shapes)
# --> 139 return super().fit(dataset=dataset, **kwargs)
#
# File ~\Desktop\Projects\BayesFlow\bayesflow\approximators\backend_approximators\backend_approximator.py:20, in BackendApproximator.fit(self, dataset, **kwargs)
#      19 def fit(self, *, dataset: keras.utils.PyDataset, **kwargs):
# ---> 20     return super().fit(x=dataset, y=None, **filter_kwargs(kwargs, super().fit))
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\keras\src\backend\jax\trainer.py:460, in JAXTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     451 (
#     452     trainable_variables,
#     453     non_trainable_variables,
#     454     optimizer_variables,
#     455     metrics_variables,
#     456 ) = state
#     458 # Setting _jax_state enables callbacks to force a state
#     459 # sync if they need to.
# --> 460 self._jax_state = {
#     461     "trainable_variables": trainable_variables,
#     462     "non_trainable_variables": non_trainable_variables,
#     463     "optimizer_variables": optimizer_variables,
#     464     "metrics_variables": metrics_variables,
#     465 }
#     466 # Dispatch callbacks. This takes care of async dispatch.
#     467 callbacks.on_train_batch_end(end_step, logs)
#
# File c:\Users\radevs\AppData\Local\anaconda3\envs\bf\Lib\site-packages\keras\src\layers\layer.py:1565, in Layer.__setattr__(self, name, value)
#    1562     object.__setattr__(self, name, value)
#    1563     return
# -> 1565 super().__setattr__(name, value)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convergence, Sampling, and Diagnostics

# %% [markdown]
# #### Loss Trajectory

# %%
f = bf.diagnostics.loss(history)

# %%
# Set the number of posterior draws you want to get
num_samples = 2000

# Obtain posterior draws with the sample method (shortcut for workflow.approximator.sample...)
post_draws = workflow.sample(conditions=validation_data, num_samples=num_samples)

# %% [markdown]
# #### Point Recovery

# %%
fig = bf.diagnostics.plots.recovery(estimates=post_draws, targets=validation_data, variable_names=par_names)

# %% [markdown]
# #### Simulation-Based Calibration

# %%
fig = bf.diagnostics.plots.calibration_ecdf(
    estimates=post_draws, 
    targets=validation_data,
    variable_names=par_names,
    difference=True,
    rank_type="distance"
)

# %% [markdown]
# #### Posterior Z-Score vs. Contraction

# %%
fig = bf.diagnostics.plots.z_score_contraction(
    estimates=post_draws, 
    targets=validation_data,
    variable_names=par_names
)

# %% [markdown]
# #### Marginal and Bivariate Posteriors

# %%
g = bf.diagnostics.plots.pairs_posterior(
    estimates=post_draws, 
    targets=validation_data,
    dataset_id=0,
    variable_names=par_names,
)

# %% [markdown]
# #### Posterior Retrodictive and Predictive Checks

# %%
def take_posterior_sample(post_draws, dataset_id, sample_id):
    """Helper function to return a single sample for a single data set."""
    posterior_sample_for_id = {var_key: post_draws[var_key][dataset_id, sample_id,...].squeeze() for var_key in post_draws.keys()}
    return posterior_sample_for_id

def take_dataset(sims, dataset_id):
    """Helper function to return a single simulation from a dictionary of simulations."""
    return {var_key: sims[var_key][dataset_id] for var_key in sims.keys()}

# %%
dataset_id = 0

list_of_resimulations = []

for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(post_draws, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))

resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)


f, ax = plt.subplots(1, 1, figsize=(12, 3))
plot_lv_trajectores(resimulation_samples, ["x", "y"], ["Prey", "Predator"], observations=observations, ax=ax)
ax.axvline([5], color="black", linestyle="dashed")

# %% [markdown]
# ## End-To-End Learning of Summary Statistics
#
# Next, we will move away from hand-crafted summary statistics, using an auxilliary network to learn the most informative statistics on the fly.

# %% [markdown]
# ### Updated Adapter

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .drop(["x", "y", "t"])
    .drop(["means", "log_vars", "auto_corrs", "cross_corr", "period"])
    .as_time_series(["observed_x", "observed_y", "observed_t"])
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")

    # Notice that we now use 'summary_variables' to indicate that these quantities will
    # be passed to the summary network before being used as a condition
    .concatenate(["observed_x", "observed_y", "observed_t"], into="summary_variables")
)
adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't']) -> 2: Drop(['means', 'log_vars', 'auto_corrs', 'cross_corr', 'period']) -> 3: AsTimeSeries -> 4: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 5: Concatenate(['observed_x', 'observed_y', 'observed_t'] -> 'summary_variables') -> 6: Standardize(include=['inference_variables', 'summary_variables'])])

# %%
e2e_workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=bf.networks.TimeSeriesNetwork(),
    inference_network=bf.networks.FlowMatching()
)

# %%
# %%time
history = e2e_workflow.fit_offline(
    data=training_data, 
    epochs=epochs, 
    batch_size=batch_size, 
    validation_data=validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 25ms/step - loss: 2.2687 - loss/inference_loss: 2.2687 - val_loss: 1.1400 - val_loss/inference_loss: 1.1400
# Epoch 2/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3590 - loss/inference_loss: 1.3590 - val_loss: 1.6073 - val_loss/inference_loss: 1.6073
# Epoch 3/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 1.1653 - loss/inference_loss: 1.1653 - val_loss: 1.2869 - val_loss/inference_loss: 1.2869
# Epoch 4/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0670 - loss/inference_loss: 1.0670 - val_loss: 1.1473 - val_loss/inference_loss: 1.1473
# Epoch 5/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.9842 - loss/inference_loss: 0.9842 - val_loss: 0.6690 - val_loss/inference_loss: 0.6690
# Epoch 6/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.9405 - loss/inference_loss: 0.9405 - val_loss: 0.9953 - val_loss/inference_loss: 0.9953
# Epoch 7/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.9115 - loss/inference_loss: 0.9115 - val_loss: 0.9477 - val_loss/inference_loss: 0.9477
# Epoch 8/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.8626 - loss/inference_loss: 0.8626 - val_loss: 0.8167 - val_loss/inference_loss: 0.8167
# Epoch 9/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8275 - loss/inference_loss: 0.8275 - val_loss: 0.8689 - val_loss/inference_loss: 0.8689
# Epoch 10/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8239 - loss/inference_loss: 0.8239 - val_loss: 0.6273 - val_loss/inference_loss: 0.6273
# Epoch 11/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.8093 - loss/inference_loss: 0.8093 - val_loss: 0.3939 - val_loss/inference_loss: 0.3939
# Epoch 12/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7412 - loss/inference_loss: 0.7412 - val_loss: 0.8991 - val_loss/inference_loss: 0.8991
# Epoch 13/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.7305 - loss/inference_loss: 0.7305 - val_loss: 0.5657 - val_loss/inference_loss: 0.5657
# Epoch 14/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6968 - loss/inference_loss: 0.6968 - val_loss: 0.8429 - val_loss/inference_loss: 0.8429
# Epoch 15/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6680 - loss/inference_loss: 0.6680 - val_loss: 0.6399 - val_loss/inference_loss: 0.6399
# Epoch 16/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6609 - loss/inference_loss: 0.6609 - val_loss: 0.3699 - val_loss/inference_loss: 0.3699
# Epoch 17/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6452 - loss/inference_loss: 0.6452 - val_loss: 0.4784 - val_loss/inference_loss: 0.4784
# Epoch 18/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6417 - loss/inference_loss: 0.6417 - val_loss: 0.5749 - val_loss/inference_loss: 0.5749
# Epoch 19/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6003 - loss/inference_loss: 0.6003 - val_loss: 0.5037 - val_loss/inference_loss: 0.5037
# Epoch 20/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.6220 - loss/inference_loss: 0.6220 - val_loss: 0.4935 - val_loss/inference_loss: 0.4935
# Epoch 21/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5983 - loss/inference_loss: 0.5983 - val_loss: 0.7539 - val_loss/inference_loss: 0.7539
# Epoch 22/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5868 - loss/inference_loss: 0.5868 - val_loss: 0.3732 - val_loss/inference_loss: 0.3732
# Epoch 23/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5590 - loss/inference_loss: 0.5590 - val_loss: 0.2708 - val_loss/inference_loss: 0.2708
# Epoch 24/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5631 - loss/inference_loss: 0.5631 - val_loss: 0.4622 - val_loss/inference_loss: 0.4622
# Epoch 25/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5488 - loss/inference_loss: 0.5488 - val_loss: 0.3147 - val_loss/inference_loss: 0.3147
# Epoch 26/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5306 - loss/inference_loss: 0.5306 - val_loss: 0.7187 - val_loss/inference_loss: 0.7187
# Epoch 27/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5268 - loss/inference_loss: 0.5268 - val_loss: 0.4026 - val_loss/inference_loss: 0.4026
# Epoch 28/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5277 - loss/inference_loss: 0.5277 - val_loss: 0.4366 - val_loss/inference_loss: 0.4366
# Epoch 29/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5041 - loss/inference_loss: 0.5041 - val_loss: 0.4486 - val_loss/inference_loss: 0.4486
# Epoch 30/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.5086 - loss/inference_loss: 0.5086 - val_loss: 0.5543 - val_loss/inference_loss: 0.5543
# Epoch 31/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5071 - loss/inference_loss: 0.5071 - val_loss: 0.6890 - val_loss/inference_loss: 0.6890
# Epoch 32/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4937 - loss/inference_loss: 0.4937 - val_loss: 0.5692 - val_loss/inference_loss: 0.5692
# Epoch 33/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4785 - loss/inference_loss: 0.4785 - val_loss: 0.2647 - val_loss/inference_loss: 0.2647
# Epoch 34/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.4986 - loss/inference_loss: 0.4986 - val_loss: 0.3774 - val_loss/inference_loss: 0.3774
# Epoch 35/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.4747 - loss/inference_loss: 0.4747 - val_loss: 0.4384 - val_loss/inference_loss: 0.4384
# Epoch 36/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.4648 - loss/inference_loss: 0.4648 - val_loss: 0.3539 - val_loss/inference_loss: 0.3539
# Epoch 37/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4733 - loss/inference_loss: 0.4733 - val_loss: 0.3904 - val_loss/inference_loss: 0.3904
# Epoch 38/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4623 - loss/inference_loss: 0.4623 - val_loss: 0.2377 - val_loss/inference_loss: 0.2377
# Epoch 39/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4633 - loss/inference_loss: 0.4633 - val_loss: 0.3823 - val_loss/inference_loss: 0.3823
# Epoch 40/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4673 - loss/inference_loss: 0.4673 - val_loss: 0.8776 - val_loss/inference_loss: 0.8776
# Epoch 41/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4574 - loss/inference_loss: 0.4574 - val_loss: 0.4681 - val_loss/inference_loss: 0.4681
# Epoch 42/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4459 - loss/inference_loss: 0.4459 - val_loss: 0.3019 - val_loss/inference_loss: 0.3019
# Epoch 43/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4483 - loss/inference_loss: 0.4483 - val_loss: 0.2308 - val_loss/inference_loss: 0.2308
# Epoch 44/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4598 - loss/inference_loss: 0.4598 - val_loss: 0.3984 - val_loss/inference_loss: 0.3984
# Epoch 45/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4389 - loss/inference_loss: 0.4389 - val_loss: 0.2369 - val_loss/inference_loss: 0.2369
# Epoch 46/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4380 - loss/inference_loss: 0.4380 - val_loss: 0.2351 - val_loss/inference_loss: 0.2351
# Epoch 47/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4529 - loss/inference_loss: 0.4529 - val_loss: 0.3818 - val_loss/inference_loss: 0.3818
# Epoch 48/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.4398 - loss/inference_loss: 0.4398 - val_loss: 0.6842 - val_loss/inference_loss: 0.6842
# Epoch 49/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4457 - loss/inference_loss: 0.4457 - val_loss: 0.5470 - val_loss/inference_loss: 0.5470
# Epoch 50/50
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4412 - loss/inference_loss: 0.4412 - val_loss: 0.5118 - val_loss/inference_loss: 0.5118
# CPU times: total: 2min 49s
# Wall time: 1min 20s

# %% [markdown]
# ### Convergence, Sampling, and Diagnostics

# %% [markdown]
# #### Loss Trajectory

# %%
history = bf.diagnostics.plots.loss(history)

# %% [markdown]
# Note, that the loss is lower since we are learning summary statistics simultaneously. How does this translate to visual diagnostics? We can check them again by sampling the posteriors of validation simulations not seen in training.

# %%
samples = e2e_workflow.sample(num_samples=250, conditions=validation_data)

# %% [markdown]
# #### Point Recovery

# %%
f = bf.diagnostics.plots.recovery(
    estimates=samples, 
    targets=validation_data
)

# %% [markdown]
# #### Simulation-Based Calibration

# %%
f = bf.diagnostics.plots.calibration_ecdf(
    estimates=samples, 
    targets=validation_data,
    difference=True 
)

# %% [markdown]
# #### Marginal and Bivariate Posteriors

# %%
f = bf.diagnostics.plots.pairs_posterior(
    estimates=samples, 
    targets=validation_data,
    dataset_id=0,
    priors=validation_data
)

# %% [markdown]
# #### Posterior Retrodictive and Predictive Checks

# %%
post_draws = samples

# %%
dataset_id = 0

list_of_resimulations = []

for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(post_draws, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))

resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)


f, ax = plt.subplots(1, 1, figsize=(12, 3))
plot_lv_trajectores(resimulation_samples, ["x", "y"], ["Prey", "Predator"], observations=observations, ax=ax)
ax.axvline([5], color="black", linestyle="dashed")

# %% [markdown]
# ## Comparing Workflows at a Glance

# %%
diag = workflow.compute_default_diagnostics(validation_data, num_samples=500)
diag
# Out:
#                           alpha      beta     gamma     delta
# NRMSE                  0.121168  0.120879  0.108853  0.120997
# Posterior Contraction  0.893647  0.891465  0.903410  0.894071
# Calibration Error      0.015439  0.009561  0.028246  0.013509

# %%
e2e_diag = e2e_workflow.compute_default_diagnostics(validation_data, num_samples=500)
e2e_diag
# Out:
#                           alpha      beta     gamma     delta
# NRMSE                  0.112403  0.115274  0.104116  0.108834
# Posterior Contraction  0.908381  0.898962  0.919787  0.918580
# Calibration Error      0.028246  0.015965  0.015965  0.019737
