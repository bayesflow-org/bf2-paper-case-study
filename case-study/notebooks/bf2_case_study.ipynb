# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"

# %%
import keras
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint

import bayesflow as bf
# Out:
# INFO:2026-01-29 10:50:09,334:jax._src.xla_bridge:822: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# INFO:bayesflow:Using backend 'jax'

# %%
np.set_printoptions(suppress=True)
rng = np.random.default_rng(2026)

# %%
def priors():
    x = rng.normal(size=4)
    # logit normal distribution scaled to range from 0.1 and 4
    theta = 1/(1+np.exp(-x)) * 3.9 + 0.1 
    return dict(
        alpha=theta[0],
        beta=theta[1],
        gamma=theta[2],
        delta=theta[3],
    )


def lotka_volterra_equations(state, t, alpha, beta, gamma, delta):
    x, y = state
    dxdt = alpha * x - beta * x * y
    dydt = - gamma * y + delta * x * y
    return [dxdt, dydt]


def ecology_model(alpha, beta, gamma, delta, t_span=[0, 5], t_steps=100, initial_state=[1, 1]):
    t = np.linspace(t_span[0], t_span[1], t_steps)
    state = odeint(lotka_volterra_equations, initial_state, t, args=(alpha, beta, gamma, delta))
    x, y = state.T
    
    return dict(
        x=x,  # Prey time series
        y=y,  # Predator time series
        t=t,  # Time vector
    )


def observation_model(x, y, t, subsample=10, obs_prob=1.0, noise_scale=0.1):

    t_steps = x.shape[0]
    
    # Add Gaussian noise to observations
    noisy_x = rng.normal(x, noise_scale)
    noisy_y = rng.normal(y, noise_scale)
    
    # Determine which time steps are observed
    step_indices = np.arange(0, t_steps, subsample)
    num_observed = int(obs_prob * len(step_indices))
    observed_indices = np.sort(rng.choice(step_indices, num_observed, replace=False))

    return {
        "observed_x": noisy_x[observed_indices],
        "observed_y": noisy_y[observed_indices],
        "observed_t": t[observed_indices]
    }

# %%
test_priors = priors()
test_priors
# Out:
# {'alpha': np.float64(1.3148445672500593),
#  'beta': np.float64(2.2834322704027272),
#  'gamma': np.float64(0.6090468149948529),
#  'delta': np.float64(3.2258970550948094)}

# %%
observation_model(**ecology_model(**test_priors))
# Out:
# {'observed_x': array([ 1.06382947,  0.30877014,  0.11606098, -0.07443925,  0.06560553,
#         -0.04026803, -0.08785976,  0.11564338,  0.04184632,  0.01804696]),
#  'observed_y': array([1.13964531, 2.09557994, 2.00040578, 1.43827232, 1.01243393,
#         0.90554781, 0.87327022, 0.362658  , 0.40740723, 0.26668791]),
#  'observed_t': array([0.        , 0.50505051, 1.01010101, 1.51515152, 2.02020202,
#         2.52525253, 3.03030303, 3.53535354, 4.04040404, 4.54545455])}

# %%
simulator = bf.make_simulator(
    [priors, ecology_model, observation_model]
)

# %%
num_trajectories = 100
samples = simulator.sample(num_trajectories)
keras.tree.map_structure(keras.ops.shape, samples)
# Out:
# {'alpha': (100, 1),
#  'beta': (100, 1),
#  'gamma': (100, 1),
#  'delta': (100, 1),
#  'x': (100, 100),
#  'y': (100, 100),
#  't': (100, 100),
#  'observed_x': (100, 10),
#  'observed_y': (100, 10),
#  'observed_t': (100, 10)}

# %%
samples["alpha"]
# Out:
# array([[1.09238481],
#        [1.4647794 ],
#        [1.46718967],
#        [1.86765678],
#        [1.8593471 ],
#        [3.27559638],
#        [2.75817106],
#        [2.93523184],
#        [2.70612517],
#        [2.39726507],
#        [2.0560526 ],
#        [3.607572  ],
#        [0.66973872],
#        [1.40523731],
#        [2.08109375],
#        [2.49904314],
#        [2.92076308],
#        [2.08483584],
#        [2.93485953],
#        [1.4365732 ],
#        [1.41297478],
#        [3.80802474],
#        [1.11911562],
#        [3.38564821],
#        [1.10575011],
#        [1.97180297],
#        [2.13494944],
#        [1.91250653],
#        [1.82551283],
#        [3.33576749],
#        [1.0608683 ],
#        [1.50590986],
#        [2.35221183],
#        [1.8294686 ],
#        [2.96640049],
#        [2.7593444 ],
#        [2.29618493],
#        [1.49921494],
#        [1.48100677],
#        [1.3320882 ],
#        [3.46743812],
#        [2.85203616],
#        [1.14260735],
#        [2.32770871],
#        [2.62924438],
#        [3.26613465],
#        [1.59616944],
#        [1.06628215],
#        [2.40840616],
#        [1.18037838],
#        [1.71328817],
#        [2.68972698],
#        [3.2626766 ],
#        [1.09372958],
#        [3.80865946],
#        [2.41634779],
#        [0.7053018 ],
#        [2.50242557],
#        [2.22113019],
#        [2.15696538],
#        [2.05616255],
#        [1.89204749],
#        [2.43469364],
#        [3.27652007],
#        [2.16969337],
#        [3.00614865],
#        [1.18186946],
#        [2.21522019],
#        [2.41687279],
#        [1.06668146],
#        [2.8807579 ],
#        [1.06812444],
#        [2.71122391],
#        [2.51786926],
#        [2.89489641],
#        [2.08167675],
#        [2.45561899],
#        [1.68787186],
#        [2.76249435],
#        [2.08557631],
#        [2.71229767],
#        [2.07121687],
#        [0.90227362],
#        [2.27574087],
#        [0.61961744],
#        [0.82421386],
#        [1.44008281],
#        [2.52096387],
#        [2.21452121],
#        [2.98961719],
#        [2.16712346],
#        [2.01045751],
#        [1.94870061],
#        [2.27289368],
#        [1.39181313],
#        [1.38422121],
#        [2.87644824],
#        [1.92953613],
#        [2.29407838],
#        [2.40335385]])

# %%
def trajectory_aggregation(traj, confidence=0.95):
    alpha = 1 - confidence
    quantiles = np.quantile(traj, [alpha/2, 0.5, 1-alpha/2], axis=0).T
    central = quantiles[:,1]
    L = quantiles[:,0]
    U = quantiles[:,2]
    return central, L, U

def plot_trajectories(
        samples, 
        variable_keys, 
        variable_names, 
        fill_colors=["blue", "darkred"], 
        legend_ncol=3,
        confidence=0.95, 
        alpha=0.8, 
        observations=None, 
        ax=None,
        figsize=(11, 5)
):
    t_span = samples["t"][0]
    
    if ax is None:
        fig, ax = plt.subplots(1, figsize=figsize)
        sns.despine()
    
    for i, key in enumerate(variable_keys):

        if observations is not None:     
            ax.scatter(observations["observed_t"], observations["observed_"+key], color=fill_colors[i], marker="x", label="Observed " + variable_names[i].lower())

        central, L, U = trajectory_aggregation(samples[key], confidence=confidence)
        ax.plot(t_span, central, color=fill_colors[i], label="Median " + variable_names[i].lower())
        ax.fill_between(t_span, L, U, color=fill_colors[i], alpha=0.2, label=rf"{int((confidence) * 100)}$\%$ Confidence Bands")

        # plot 20 trajectory samples
        for j in range(20):
            if j == 0:
                label = f"{variable_names[i]} trajectories"
            else:
                label = None
            ax.plot(t_span, samples[key][j], color=fill_colors[i], alpha=0.2, label=label)
        

    ax.legend(
        loc="upper center",
        bbox_to_anchor=(0.5, -0.2),
        ncol=legend_ncol,
        frameon=True,
        fontsize=14
    )
    ax.set_xlabel("t", fontsize=14)
    ax.set_ylabel("population", fontsize=14)
    plt.tight_layout()
    return fig

# %%
f = plot_trajectories(samples, ["x", "y"], ["Prey", "Predator"])
f.savefig('../figures/sim_trajectories.pdf')

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .drop(["x", "y", "t"])
    .as_time_series(["observed_x", "observed_y", "observed_t"])
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")
    .concatenate(["observed_x", "observed_y", "observed_t"], into="summary_variables")
)

# %%
adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't']) -> 2: AsTimeSeries -> 3: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 4: Concatenate(['observed_x', 'observed_y', 'observed_t'] -> 'summary_variables')])

# %%
time_series_network = bf.networks.TimeSeriesNetwork(summary_dim=32)

# %%
flow_matching = bf.networks.FlowMatching()

# %%
e2e_workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=time_series_network,
    inference_network=flow_matching
)

# %%
training_data = e2e_workflow.simulate(5000)
validation_data = e2e_workflow.simulate(300)

# %%
history = e2e_workflow.fit_offline(
    data=training_data, 
    epochs=100, 
    batch_size=32, 
    validation_data=validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - loss: 2.0980 - val_loss: 1.1244
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3696 - val_loss: 1.1304
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2106 - val_loss: 1.0734
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1158 - val_loss: 1.0092
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0129 - val_loss: 0.9458
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9532 - val_loss: 0.8951
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8982 - val_loss: 0.8305
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8759 - val_loss: 0.7678
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8474 - val_loss: 0.8535
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7998 - val_loss: 0.7435
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7822 - val_loss: 0.6863
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7435 - val_loss: 0.6975
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7451 - val_loss: 0.6829
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6932 - val_loss: 0.6471
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6861 - val_loss: 0.6606
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6536 - val_loss: 0.6235
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6525 - val_loss: 0.5750
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6243 - val_loss: 0.5815
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6201 - val_loss: 0.5292
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5886 - val_loss: 0.5706
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5966 - val_loss: 0.6024
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5889 - val_loss: 0.5278
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5540 - val_loss: 0.6034
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5827 - val_loss: 0.5595
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5602 - val_loss: 0.5878
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5624 - val_loss: 0.5544
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5405 - val_loss: 0.5023
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5418 - val_loss: 0.5032
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5388 - val_loss: 0.4892
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5283 - val_loss: 0.4921
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5113 - val_loss: 0.4898
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5047 - val_loss: 0.4820
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5036 - val_loss: 0.5002
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4856 - val_loss: 0.5314
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5190 - val_loss: 0.4147
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4819 - val_loss: 0.4791
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4949 - val_loss: 0.4683
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4970 - val_loss: 0.4792
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4832 - val_loss: 0.4311
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4861 - val_loss: 0.4907
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4749 - val_loss: 0.4475
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4558 - val_loss: 0.4242
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4660 - val_loss: 0.4505
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4513 - val_loss: 0.3964
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4460 - val_loss: 0.4223
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4698 - val_loss: 0.4719
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4486 - val_loss: 0.4920
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4423 - val_loss: 0.4374
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4508 - val_loss: 0.4310
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4373 - val_loss: 0.4365
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4226 - val_loss: 0.3752
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4358 - val_loss: 0.4811
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4408 - val_loss: 0.4675
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4199 - val_loss: 0.4889
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4204 - val_loss: 0.4207
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4218 - val_loss: 0.4312
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4222 - val_loss: 0.3700
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4196 - val_loss: 0.3477
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4219 - val_loss: 0.4466
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4080 - val_loss: 0.4011
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4154 - val_loss: 0.3977
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4165 - val_loss: 0.3740
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4052 - val_loss: 0.3676
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3957 - val_loss: 0.4032
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4121 - val_loss: 0.4179
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3994 - val_loss: 0.4311
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4143 - val_loss: 0.4173
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3921 - val_loss: 0.4423
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4005 - val_loss: 0.3973
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3895 - val_loss: 0.3961
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3869 - val_loss: 0.3989
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3854 - val_loss: 0.3759
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3647 - val_loss: 0.4206
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3877 - val_loss: 0.3814
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3875 - val_loss: 0.4071
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3861 - val_loss: 0.3788
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3869 - val_loss: 0.3507
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3887 - val_loss: 0.3482
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3816 - val_loss: 0.3751
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3764 - val_loss: 0.4508
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3799 - val_loss: 0.4059
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3741 - val_loss: 0.3742
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3771 - val_loss: 0.3899
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3695 - val_loss: 0.4141
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3784 - val_loss: 0.3547
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3679 - val_loss: 0.3718
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3705 - val_loss: 0.3638
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3690 - val_loss: 0.3750
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3562 - val_loss: 0.4179
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3654 - val_loss: 0.3806
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3685 - val_loss: 0.3896
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3649 - val_loss: 0.3683
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3727 - val_loss: 0.3539
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3662 - val_loss: 0.4217
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3690 - val_loss: 0.3801
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3657 - val_loss: 0.3852
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3604 - val_loss: 0.3441
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3758 - val_loss: 0.3811
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3625 - val_loss: 0.4131
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3623 - val_loss: 0.3330

# %%
fig_size = (20, 5)

figures = e2e_workflow.plot_default_diagnostics(
    test_data=validation_data,
    variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"],
    loss_kwargs={"figsize": fig_size, "label_fontsize": 16, "title_fontsize": 20},
    recovery_kwargs={
        "figsize": fig_size,
        "label_fontsize": 16,
        "title_fontsize": 20,
    },
    calibration_ecdf_kwargs={
        "figsize": fig_size,
        "legend_fontsize": 12,
        "difference": True,
        "label_fontsize": 16,
    },
    z_score_contraction_kwargs={"figsize": fig_size, "label_fontsize": 16},
)

for plot_name, fig in figures.items():
    fig_path = f"../figures/e2e_{plot_name}.pdf"
    fig.savefig(fig_path)
    plt.close(fig)

# %%
metrics = e2e_workflow.compute_default_diagnostics(
    test_data=validation_data, 
    variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"]
)

# %%
metrics
# Out:
#                        $\alpha$   $\beta$  $\gamma$  $\delta$
# NRMSE                  0.113453  0.108707  0.102999  0.104992
# Posterior Contraction  0.941303  0.913495  0.931970  0.928092
# Calibration Error      0.008684  0.018509  0.015263  0.018070

# %%
estimates = e2e_workflow.sample(num_samples=300, conditions=validation_data)

for i in range(10):
    f = bf.diagnostics.plots.pairs_posterior(
        estimates=estimates, 
        targets=validation_data,
        dataset_id=i,
        priors=validation_data,
        variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"],
        label_fontsize=16,
        legend_fontsize=16
    )

    if i <= 2:
        fig_path = f"../figures/e2e_posterior_{i}.pdf"
        fig.savefig(fig_path)
        plt.close(fig)

# %%
def take_posterior_sample(post_draws, dataset_id, sample_id):
    """Helper function to return a single sample for a single data set."""
    posterior_sample_for_id = {var_key: post_draws[var_key][dataset_id, sample_id,...].squeeze() for var_key in post_draws.keys()}
    return posterior_sample_for_id

def take_dataset(sims, dataset_id):
    """Helper function to return a single simulation from a dictionary of simulations."""
    return {var_key: sims[var_key][dataset_id] for var_key in sims.keys()}

# %%
dataset_id = 0
num_samples = 300

list_of_resimulations = []

posterior_draws = e2e_workflow.sample(num_samples=300, conditions=validation_data)

for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(posterior_draws, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))

resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)

f = plot_trajectories(resimulation_samples, ["x", "y"], ["Prey", "Predator"], observations=observations, legend_ncol=4)
ax.axvline([5], color="black", linestyle="dashed")
f.savefig("../figures/e2e_trajectories.pdf")

# %% [markdown]
# ## Expert Summary Statistics

# %%
from scipy.signal import periodogram

def period(observed_x, t_span=[0, 5], t_steps=500):
    """
    Computes the dominant period of observed_x from a periodogram.
    """
    f, Pxx = periodogram(observed_x, t_steps/(t_span[1]-t_span[0]))
    freq_dominant = f[np.argmax(Pxx)]
    T = 1 / freq_dominant
    return T


def autocorr(trajectory, lags):
    """
    Computes the autocorrelation for each specified lag in a trajectory.
    
    Parameters
    ----------
    trajectory : np.ndarray
        The time series data, assumed to be a 1D array.
    lags : np.ndarray or list
        The lags at which to compute the autocorrelation.
    
    Returns
    -------
    auto_correlation : np.ndarray
        Autocorrelation values at each specified lag.
    """
    # Calculate the mean and variance of the trajectory for normalization
    mean = np.mean(trajectory)
    var = np.var(trajectory)
    
    # Initialize an array to hold the autocorrelation values
    auto_correlation = np.zeros(len(lags))
    
    # Compute autocorrelation for each lag
    for i, lag in enumerate(lags):
        if lag == 0:
            # Autocorrelation at lag 0 is always 1
            auto_correlation[i] = 1
        elif lag >= len(trajectory):
            # If the lag is equal to or greater than the length of the trajectory, autocorrelation is undefined (set to 0)
            auto_correlation[i] = 0
        else:
            # Compute covariance and then autocorrelation
            cov = np.mean((trajectory[:-lag] - mean) * (trajectory[lag:] - mean))
            auto_correlation[i] = cov / var

    if np.any(np.isnan(auto_correlation)):
        print(auto_correlation)
            
    return auto_correlation

def crosscorr(x, y):
    """
    Computes the cross-correlation (Pearson correlation coefficient) between two trajectories at zero lag.

    Parameters
    ----------
    x : np.ndarray
        The first time series data, assumed to be a 1D array of length n.
    y : np.ndarray
        The second time series data, assumed to be a 1D array of length n.

    Returns
    -------
    float
        The cross-correlation coefficient.
    """
    # Compute the mean and standard deviation of both time series
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    std_x = np.std(x)
    std_y = np.std(y)

    # Compute the covariance and the correlation coefficient
    covariance = np.mean((x - mean_x) * (y - mean_y))
    correlation = covariance / (std_x * std_y)

    return correlation

def expert_stats(observed_x, observed_y, lags=[2,5]):
    """Computes fixed size statistics for an observed population trajectory

    Parameters
    ----------
    observed_x : np.ndarray with shape (num_observations, )
    observed_y : np.ndarray with shape (num_observations, )

    Returns
    -------
    dictionary with the following keys and values
    means      : np.ndarray with shape (2,)
    log_vars   : np.ndarray with shape (2,)
    auto_corrs : np.ndarray with shape (2*num_lags,)
        auto-correlation of each timeseries at lags 0.2 and 0.4 time units
    cross_corr : np.ndarray with shape (1,)
        the cross-correlation between the two time series
    period     : np.ndarray with shape (1,)
    """
    means = np.array([observed_x.mean(), observed_y.mean()])
    log_vars = np.log(np.array([observed_x.var(), observed_y.var()]))
    auto_corrs = np.array([
        autocorr(observed_x,lags),
        autocorr(observed_y,lags),
    ]).flatten()
    cross_corr = crosscorr(observed_x, observed_y)
    T = period(observed_x)
    
    return dict(
        means=means,
        log_vars=log_vars,
        auto_corrs=auto_corrs,
        cross_corr=cross_corr,
        period=T,
    )

# %%
expert_simulator = bf.make_simulator(
    [priors, ecology_model, observation_model, expert_stats]
)

# %%
expert_adapter = (
    bf.adapters.Adapter()

    # convert from numpy's default float64 to deep learning friendly float32
    .convert_dtype("float64", "float32")

    # drop unobserved full trajectories and raw observations (optional)
    .drop(["x", "y", "t", "observed_x", "observed_y", "observed_t"])

    # rename the variables to match the required approximator inputs
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")
    .concatenate(["means", "log_vars", "auto_corrs", "cross_corr", "period"], into="inference_conditions")

)

# %%
expert_adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't', 'observed_x', 'observed_y', 'observed_t']) -> 2: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 3: Concatenate(['means', 'log_vars', 'auto_corrs', 'cross_corr', 'period'] -> 'inference_conditions')])

# %%
quantile_levels = np.linspace(0.1, 0.9, 5)

# %%
point_inference_network = bf.networks.PointInferenceNetwork(
    scores=dict(
        mean=bf.scores.MeanScore(),
        quantiles=bf.scores.QuantileScore(quantile_levels)
    )
)

# %%
point_estimation_workflow = bf.BasicWorkflow(
    simulator=expert_simulator,
    adapter=expert_adapter,
    inference_network=point_inference_network
)

# %%
point_estimator_history = point_estimation_workflow.fit_online(
    epochs=100,
    num_batches_per_epoch=157,
    batch_size=32,
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - loss: 0.6650 - mean/inference_mean: 0.9663 - quantiles/inference_quantiles: 0.3638
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.4578 - mean/inference_mean: 0.6386 - quantiles/inference_quantiles: 0.2769
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.2785 - mean/inference_mean: 0.3524 - quantiles/inference_quantiles: 0.2046
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.3262 - mean/inference_mean: 0.4380 - quantiles/inference_quantiles: 0.2143
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - loss: 0.1956 - mean/inference_mean: 0.2317 - quantiles/inference_quantiles: 0.1596
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.2148 - mean/inference_mean: 0.2747 - quantiles/inference_quantiles: 0.1549
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2220 - mean/inference_mean: 0.2720 - quantiles/inference_quantiles: 0.1720
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.2106 - mean/inference_mean: 0.2584 - quantiles/inference_quantiles: 0.1629
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1459 - mean/inference_mean: 0.1580 - quantiles/inference_quantiles: 0.1337
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1604 - mean/inference_mean: 0.1849 - quantiles/inference_quantiles: 0.1359
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1919 - mean/inference_mean: 0.2418 - quantiles/inference_quantiles: 0.1420
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1726 - mean/inference_mean: 0.1950 - quantiles/inference_quantiles: 0.1503
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1604 - mean/inference_mean: 0.2024 - quantiles/inference_quantiles: 0.1184
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1695 - mean/inference_mean: 0.2059 - quantiles/inference_quantiles: 0.1332
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.1961 - mean/inference_mean: 0.2500 - quantiles/inference_quantiles: 0.1421
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1801 - mean/inference_mean: 0.2244 - quantiles/inference_quantiles: 0.1358
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1732 - mean/inference_mean: 0.2104 - quantiles/inference_quantiles: 0.1360
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - loss: 0.
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - loss: 0.1296 - mean/inference_mean: 0.1485 - quantiles/inference_quantiles: 0.1107
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1239 - mean/inference_mean: 0.1444 - quantiles/inference_quantiles: 0.1033
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.1306 - mean/inference_mean: 0.1515 - quantiles/inference_quantiles: 0.1097
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.1248 - mean/inference_mean: 0.1386 - quantiles/inference_quantiles: 0.1110
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0931 - mean/inference_mean: 0.0997 - quantiles/inference_quantiles: 0.0864
# INFO:bayesflow:Training completed in 4.70 minutes.

# %%
f = bf.diagnostics.loss(history)

# %%
validation_data = expert_simulator.sample(300)
variable_names = [r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"]

# %%
# Set the number of posterior draws you want to get
point_estimates = point_estimation_workflow.estimate(conditions=validation_data)

# %%
keras.tree.map_structure(keras.ops.shape, point_estimates)
# Out:
# {'alpha': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'beta': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'gamma': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'delta': {'mean': (300, 1), 'quantiles': (300, 5, 1)}}

# %%
marker_mapping = dict(quantiles="_", mean="*")

# %%
point_recovery = bf.diagnostics.plots.recovery_from_estimates(
    estimates=point_estimates, 
    targets=validation_data, 
    variable_names=variable_names,
    marker_mapping=marker_mapping
)

# %%
f = bf.diagnostics.plots.calibration_ecdf_from_quantiles(
    estimates=point_estimates, 
    targets=validation_data,
    quantile_levels=quantile_levels,
    difference=False,
    variable_names=variable_names,
)

# %%
posterior_bounds_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,[0,-1]], {k:v["quantiles"] for k,v in point_estimates.items()}
)

# %%
from scipy.stats import norm

std_normal_quantiles = norm.ppf(quantile_levels[[0,-1]])
std_normal_quantiles
# Out:
# array([-1.28155157,  1.28155157])

# %%
# calculate interpolation value for mean and standard deviation
alpha = std_normal_quantiles[0] / (std_normal_quantiles[0] - std_normal_quantiles[1])
beta = (std_normal_quantiles[0] - 1) / (std_normal_quantiles[0] - std_normal_quantiles[1])

# %%
posterior_means_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,0] * (1-alpha) + v[:,1] * alpha, posterior_bounds_from_quantiles
)
posterior_stds_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,0] * (alpha-beta) + v[:,1] * (beta-alpha), posterior_bounds_from_quantiles
)

# %%
num_samples = 300

# sample from normal distribution consistent with quantile estimates
posterior_draws_from_quantiles = keras.tree.map_structure(
    lambda v: rng.normal(
    loc=v[:,0] * (1-alpha) + v[:,1] * alpha, 
    scale=v[:,0] * (alpha-beta) + v[:,1] * (beta-alpha),
    size=(300, num_samples))[..., None], posterior_bounds_from_quantiles
)

# %%
dataset_id = 1
list_of_resimulations = []
for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(posterior_draws_from_quantiles, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))
resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)

f, ax = plt.subplots(1, 1, figsize=(12.5, 5))
plot_trajectories(resimulation_samples, ["x", "y"], ["Prey", "Predator"], observations=observations, legend_ncol=4, ax=ax)
