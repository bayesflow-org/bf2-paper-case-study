# %%
import os
os.environ["KERAS_BACKEND"] = "jax"
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"

# %%
import keras
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.integrate import odeint

import bayesflow as bf
# Out:
# INFO:2026-02-05 16:29:36,084:jax._src.xla_bridge:822: Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# INFO:bayesflow:Using backend 'jax'

# %%
np.set_printoptions(suppress=True)
rng = np.random.default_rng(2026)

# %%
def priors():
    x = rng.normal(size=4)
    # logit normal distribution scaled to range from 0.1 and 4
    theta = 1/(1+np.exp(-x)) * 3.9 + 0.1 
    return dict(
        alpha=theta[0],
        beta=theta[1],
        gamma=theta[2],
        delta=theta[3],
    )


def lotka_volterra_equations(state, t, alpha, beta, gamma, delta):
    x, y = state
    dxdt = alpha * x - beta * x * y
    dydt = - gamma * y + delta * x * y
    return [dxdt, dydt]


def ecology_model(alpha, beta, gamma, delta, t_span=[0, 5], t_steps=100, initial_state=[1, 1]):
    t = np.linspace(t_span[0], t_span[1], t_steps)
    state = odeint(lotka_volterra_equations, initial_state, t, args=(alpha, beta, gamma, delta))
    x, y = state.T
    
    return dict(
        x=x,  # Prey time series
        y=y,  # Predator time series
        t=t,  # Time vector
    )


def observation_model(x, y, t, subsample=10, obs_prob=1.0, noise_scale=0.1):

    t_steps = x.shape[0]
    
    # Add Gaussian noise to observations
    noisy_x = rng.normal(x, noise_scale)
    noisy_y = rng.normal(y, noise_scale)
    
    # Determine which time steps are observed
    step_indices = np.arange(0, t_steps, subsample)
    num_observed = int(obs_prob * len(step_indices))
    observed_indices = np.sort(rng.choice(step_indices, num_observed, replace=False))

    return {
        "observed_x": noisy_x[observed_indices],
        "observed_y": noisy_y[observed_indices],
        "observed_t": t[observed_indices]
    }

# %%
observation_model(**ecology_model(**priors()))
# Out:
# {'observed_x': array([ 1.06382947,  0.30877014,  0.11606098, -0.07443925,  0.06560553,
#         -0.04026803, -0.08785976,  0.11564338,  0.04184632,  0.01804696]),
#  'observed_y': array([1.13964531, 2.09557994, 2.00040578, 1.43827232, 1.01243393,
#         0.90554781, 0.87327022, 0.362658  , 0.40740723, 0.26668791]),
#  'observed_t': array([0.        , 0.50505051, 1.01010101, 1.51515152, 2.02020202,
#         2.52525253, 3.03030303, 3.53535354, 4.04040404, 4.54545455])}

# %%
simulator = bf.make_simulator(
    [priors, ecology_model, observation_model]
)

# %%
num_trajectories = 100
samples = simulator.sample(num_trajectories)
keras.tree.map_structure(keras.ops.shape, samples)
# Out:
# {'alpha': (100, 1),
#  'beta': (100, 1),
#  'gamma': (100, 1),
#  'delta': (100, 1),
#  'x': (100, 100),
#  'y': (100, 100),
#  't': (100, 100),
#  'observed_x': (100, 10),
#  'observed_y': (100, 10),
#  'observed_t': (100, 10)}

# %%
samples["alpha"]
# Out:
# array([[1.09238481],
#        [1.4647794 ],
#        [1.46718967],
#        [1.86765678],
#        [1.8593471 ],
#        [3.27559638],
#        [2.75817106],
#        [2.93523184],
#        [2.70612517],
#        [2.39726507],
#        [2.0560526 ],
#        [3.607572  ],
#        [0.66973872],
#        [1.40523731],
#        [2.08109375],
#        [2.49904314],
#        [2.92076308],
#        [2.08483584],
#        [2.93485953],
#        [1.4365732 ],
#        [1.41297478],
#        [3.80802474],
#        [1.11911562],
#        [3.38564821],
#        [1.10575011],
#        [1.97180297],
#        [2.13494944],
#        [1.91250653],
#        [1.82551283],
#        [3.33576749],
#        [1.0608683 ],
#        [1.50590986],
#        [2.35221183],
#        [1.8294686 ],
#        [2.96640049],
#        [2.7593444 ],
#        [2.29618493],
#        [1.49921494],
#        [1.48100677],
#        [1.3320882 ],
#        [3.46743812],
#        [2.85203616],
#        [1.14260735],
#        [2.32770871],
#        [2.62924438],
#        [3.26613465],
#        [1.59616944],
#        [1.06628215],
#        [2.40840616],
#        [1.18037838],
#        [1.71328817],
#        [2.68972698],
#        [3.2626766 ],
#        [1.09372958],
#        [3.80865946],
#        [2.41634779],
#        [0.7053018 ],
#        [2.50242557],
#        [2.22113019],
#        [2.15696538],
#        [2.05616255],
#        [1.89204749],
#        [2.43469364],
#        [3.27652007],
#        [2.16969337],
#        [3.00614865],
#        [1.18186946],
#        [2.21522019],
#        [2.41687279],
#        [1.06668146],
#        [2.8807579 ],
#        [1.06812444],
#        [2.71122391],
#        [2.51786926],
#        [2.89489641],
#        [2.08167675],
#        [2.45561899],
#        [1.68787186],
#        [2.76249435],
#        [2.08557631],
#        [2.71229767],
#        [2.07121687],
#        [0.90227362],
#        [2.27574087],
#        [0.61961744],
#        [0.82421386],
#        [1.44008281],
#        [2.52096387],
#        [2.21452121],
#        [2.98961719],
#        [2.16712346],
#        [2.01045751],
#        [1.94870061],
#        [2.27289368],
#        [1.39181313],
#        [1.38422121],
#        [2.87644824],
#        [1.92953613],
#        [2.29407838],
#        [2.40335385]])

# %%
def trajectory_aggregation(traj, confidence=0.95):
    alpha = 1 - confidence
    quantiles = np.quantile(traj, [alpha/2, 0.5, 1-alpha/2], axis=0).T
    central = quantiles[:,1]
    L = quantiles[:,0]
    U = quantiles[:,2]
    return central, L, U

def plot_trajectories(
        samples, 
        variable_keys, 
        variable_names, 
        fill_colors=["blue", "darkred"], 
        legend_ncol=3,
        confidence=0.95, 
        alpha=0.8, 
        observations=None, 
        ax=None,
        figsize=(11, 5)
):
    t_span = samples["t"][0]
    
    if ax is None:
        fig, ax = plt.subplots(1, figsize=figsize)
        sns.despine()
    
    for i, key in enumerate(variable_keys):

        if observations is not None:     
            ax.scatter(observations["observed_t"], observations["observed_"+key], color=fill_colors[i], marker="x", label="Observed " + variable_names[i].lower())
            ax.axvline(observations["observed_t"].max(), color="black", linestyle="dashed")

        central, L, U = trajectory_aggregation(samples[key], confidence=confidence)
        ax.plot(t_span, central, color=fill_colors[i], label="Median " + variable_names[i].lower())
        ax.fill_between(t_span, L, U, color=fill_colors[i], alpha=0.2, label=rf"{int((confidence) * 100)}$\%$ Confidence Bands")

        # plot 20 trajectory samples
        for j in range(20):
            if j == 0:
                label = f"{variable_names[i]} trajectories"
            else:
                label = None
            ax.plot(t_span, samples[key][j], color=fill_colors[i], alpha=0.2, label=label)
        

    ax.legend(
        loc="upper center",
        bbox_to_anchor=(0.5, -0.2),
        ncol=legend_ncol,
        frameon=True,
        fontsize=14
    )
    ax.set_xlabel("t", fontsize=14)
    ax.set_ylabel("population", fontsize=14)
    plt.tight_layout()
    return fig

# %%
f = plot_trajectories(samples, ["x", "y"], ["Prey", "Predator"])
# For saving only
# f.savefig('../figures/sim_trajectories.pdf')

# %%
adapter = (
    bf.adapters.Adapter()
    .convert_dtype("float64", "float32")
    .drop(["x", "y", "t"])
    .as_time_series(["observed_x", "observed_y", "observed_t"])
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")
    .concatenate(["observed_x", "observed_y", "observed_t"], into="summary_variables")
)

# %%
adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't']) -> 2: AsTimeSeries -> 3: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 4: Concatenate(['observed_x', 'observed_y', 'observed_t'] -> 'summary_variables')])

# %%
time_series_network = bf.networks.TimeSeriesNetwork(summary_dim=32)

# %%
flow_matching = bf.networks.FlowMatching()

# %%
workflow = bf.BasicWorkflow(
    simulator=simulator,
    adapter=adapter,
    summary_network=time_series_network,
    inference_network=flow_matching
)

# %%
training_data = workflow.simulate(5000)
validation_data = workflow.simulate(300)

# %%
history = workflow.fit_offline(
    data=training_data, 
    epochs=100, 
    batch_size=32, 
    validation_data=validation_data
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OfflineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - loss: 2.1515 - val_loss: 1.1891
# Epoch 2/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3728 - val_loss: 1.0284
# Epoch 3/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1850 - val_loss: 0.9934
# Epoch 4/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0765 - val_loss: 0.9948
# Epoch 5/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0483 - val_loss: 0.9438
# Epoch 6/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9829 - val_loss: 0.9284
# Epoch 7/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9180 - val_loss: 0.8229
# Epoch 8/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8663 - val_loss: 0.7889
# Epoch 9/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8438 - val_loss: 0.8180
# Epoch 10/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8269 - val_loss: 0.7333
# Epoch 11/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7856 - val_loss: 0.8475
# Epoch 12/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7508 - val_loss: 0.7353
# Epoch 13/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7349 - val_loss: 0.7667
# Epoch 14/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7080 - val_loss: 0.6490
# Epoch 15/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6867 - val_loss: 0.6144
# Epoch 16/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6766 - val_loss: 0.6418
# Epoch 17/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6319 - val_loss: 0.6782
# Epoch 18/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6218 - val_loss: 0.5901
# Epoch 19/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5988 - val_loss: 0.5867
# Epoch 20/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5954 - val_loss: 0.5204
# Epoch 21/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5679 - val_loss: 0.5551
# Epoch 22/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5792 - val_loss: 0.5436
# Epoch 23/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5706 - val_loss: 0.5521
# Epoch 24/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5650 - val_loss: 0.5377
# Epoch 25/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5371 - val_loss: 0.5673
# Epoch 26/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5387 - val_loss: 0.4887
# Epoch 27/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5313 - val_loss: 0.5485
# Epoch 28/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5328 - val_loss: 0.5065
# Epoch 29/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5132 - val_loss: 0.5172
# Epoch 30/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5103 - val_loss: 0.4558
# Epoch 31/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5060 - val_loss: 0.4700
# Epoch 32/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5035 - val_loss: 0.5044
# Epoch 33/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4954 - val_loss: 0.5288
# Epoch 34/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4819 - val_loss: 0.5249
# Epoch 35/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4941 - val_loss: 0.4574
# Epoch 36/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4707 - val_loss: 0.4232
# Epoch 37/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4730 - val_loss: 0.5101
# Epoch 38/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4751 - val_loss: 0.4785
# Epoch 39/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4755 - val_loss: 0.4113
# Epoch 40/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4783 - val_loss: 0.5378
# Epoch 41/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4595 - val_loss: 0.4676
# Epoch 42/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4607 - val_loss: 0.4952
# Epoch 43/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4462 - val_loss: 0.4757
# Epoch 44/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4515 - val_loss: 0.4855
# Epoch 45/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4452 - val_loss: 0.4574
# Epoch 46/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4379 - val_loss: 0.4655
# Epoch 47/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4490 - val_loss: 0.5230
# Epoch 48/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4277 - val_loss: 0.4722
# Epoch 49/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4413 - val_loss: 0.4418
# Epoch 50/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4283 - val_loss: 0.4432
# Epoch 51/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4316 - val_loss: 0.4578
# Epoch 52/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4127 - val_loss: 0.4276
# Epoch 53/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4247 - val_loss: 0.4497
# Epoch 54/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4169 - val_loss: 0.4406
# Epoch 55/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4275 - val_loss: 0.4000
# Epoch 56/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4107 - val_loss: 0.4066
# Epoch 57/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3958 - val_loss: 0.3857
# Epoch 58/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4092 - val_loss: 0.4643
# Epoch 59/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4101 - val_loss: 0.3639
# Epoch 60/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4091 - val_loss: 0.4203
# Epoch 61/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4045 - val_loss: 0.4164
# Epoch 62/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4065 - val_loss: 0.4094
# Epoch 63/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4082 - val_loss: 0.3497
# Epoch 64/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4010 - val_loss: 0.3859
# Epoch 65/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3969 - val_loss: 0.3936
# Epoch 66/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3918 - val_loss: 0.4017
# Epoch 67/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3926 - val_loss: 0.4272
# Epoch 68/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3974 - val_loss: 0.4320
# Epoch 69/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3946 - val_loss: 0.3689
# Epoch 70/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3878 - val_loss: 0.3845
# Epoch 71/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4022 - val_loss: 0.3873
# Epoch 72/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3828 - val_loss: 0.4282
# Epoch 73/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3739 - val_loss: 0.3837
# Epoch 74/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3764 - val_loss: 0.3922
# Epoch 75/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3721 - val_loss: 0.3866
# Epoch 76/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3783 - val_loss: 0.3587
# Epoch 77/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3911 - val_loss: 0.3603
# Epoch 78/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3737 - val_loss: 0.4200
# Epoch 79/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3737 - val_loss: 0.3538
# Epoch 80/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3680 - val_loss: 0.3540
# Epoch 81/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3683 - val_loss: 0.3508
# Epoch 82/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3555 - val_loss: 0.3816
# Epoch 83/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3718 - val_loss: 0.4107
# Epoch 84/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3702 - val_loss: 0.3803
# Epoch 85/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3696 - val_loss: 0.3324
# Epoch 86/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3644 - val_loss: 0.3469
# Epoch 87/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3678 - val_loss: 0.3631
# Epoch 88/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3731 - val_loss: 0.3367
# Epoch 89/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3657 - val_loss: 0.3573
# Epoch 90/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3617 - val_loss: 0.3557
# Epoch 91/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3531 - val_loss: 0.3592
# Epoch 92/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3626 - val_loss: 0.3843
# Epoch 93/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3579 - val_loss: 0.3389
# Epoch 94/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3714 - val_loss: 0.3941
# Epoch 95/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3681 - val_loss: 0.3662
# Epoch 96/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3639 - val_loss: 0.3405
# Epoch 97/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3656 - val_loss: 0.3901
# Epoch 98/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3579 - val_loss: 0.3500
# Epoch 99/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3529 - val_loss: 0.3891
# Epoch 100/100
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3644 - val_loss: 0.3462

# %%
fig_size = (20, 5)

figures = workflow.plot_default_diagnostics(
    test_data=validation_data,
    variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"],
    loss_kwargs={"figsize": fig_size, "label_fontsize": 16, "title_fontsize": 20},
    recovery_kwargs={
        "figsize": fig_size,
        "label_fontsize": 16,
        "title_fontsize": 20,
    },
    calibration_ecdf_kwargs={
        "figsize": fig_size,
        "legend_fontsize": 12,
        "difference": True,
        "label_fontsize": 16,
    },
    z_score_contraction_kwargs={"figsize": fig_size, "label_fontsize": 16},
)
# For saving only
# 
# for plot_name, fig in figures.items():
#     fig_path = f"../figures/e2e_{plot_name}.pdf"
#     fig.savefig(fig_path)
#     plt.close(fig)

# %%
metrics = workflow.compute_default_diagnostics(
    test_data=validation_data, 
    variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"]
)

# %%
metrics
# Out:
#                        $\alpha$   $\beta$  $\gamma$  $\delta$
# NRMSE                  0.113377  0.107530  0.102825  0.104310
# Posterior Contraction  0.940348  0.920263  0.928752  0.933114
# Calibration Error      0.018070  0.011842  0.008509  0.020789

# %%
estimates = workflow.sample(num_samples=300, conditions=validation_data)


f = bf.diagnostics.plots.pairs_posterior(
    estimates=estimates, 
    targets=validation_data,
    dataset_id=0,
    priors=validation_data,
    variable_names=[r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"],
    label_fontsize=16,
    legend_fontsize=16
)

# For saving only
# fig_path = f"../figures/e2e_posterior_0.pdf"
# f.savefig(fig_path)

# %%
def take_posterior_sample(post_draws, dataset_id, sample_id):
    """Helper function to return a single sample for a single data set."""
    posterior_sample_for_id = {var_key: post_draws[var_key][dataset_id, sample_id,...].squeeze() for var_key in post_draws.keys()}
    return posterior_sample_for_id

def take_dataset(sims, dataset_id):
    """Helper function to return a single simulation from a dictionary of simulations."""
    return {var_key: sims[var_key][dataset_id] for var_key in sims.keys()}

# %%
dataset_id = 0
num_samples = 300

list_of_resimulations = []

posterior_draws = workflow.sample(num_samples=300, conditions=validation_data)

for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(posterior_draws, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))

resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)

f = plot_trajectories(resimulation_samples, ["x", "y"], ["Prey", "Predator"], observations=observations, legend_ncol=4, figsize=(12.5, 5))
# For saving only
f.savefig("../figures/e2e_trajectories.pdf")

# %% [markdown]
# ## Expert Summary Statistics

# %%
from scipy.signal import periodogram

def period(observed_x, t_span=[0, 5], t_steps=500):
    """
    Computes the dominant period of observed_x from a periodogram.
    """
    f, Pxx = periodogram(observed_x, t_steps/(t_span[1]-t_span[0]))
    freq_dominant = f[np.argmax(Pxx)]
    T = 1 / freq_dominant
    return T


def autocorr(trajectory, lags):
    """
    Computes the autocorrelation for each specified lag in a trajectory.
    
    Parameters
    ----------
    trajectory : np.ndarray
        The time series data, assumed to be a 1D array.
    lags : np.ndarray or list
        The lags at which to compute the autocorrelation.
    
    Returns
    -------
    auto_correlation : np.ndarray
        Autocorrelation values at each specified lag.
    """
    # Calculate the mean and variance of the trajectory for normalization
    mean = np.mean(trajectory)
    var = np.var(trajectory)
    
    # Initialize an array to hold the autocorrelation values
    auto_correlation = np.zeros(len(lags))
    
    # Compute autocorrelation for each lag
    for i, lag in enumerate(lags):
        if lag == 0:
            # Autocorrelation at lag 0 is always 1
            auto_correlation[i] = 1
        elif lag >= len(trajectory):
            # If the lag is equal to or greater than the length of the trajectory, autocorrelation is undefined (set to 0)
            auto_correlation[i] = 0
        else:
            # Compute covariance and then autocorrelation
            cov = np.mean((trajectory[:-lag] - mean) * (trajectory[lag:] - mean))
            auto_correlation[i] = cov / var

    if np.any(np.isnan(auto_correlation)):
        print(auto_correlation)
            
    return auto_correlation

def crosscorr(x, y):
    """
    Computes the cross-correlation (Pearson correlation coefficient) between two trajectories at zero lag.

    Parameters
    ----------
    x : np.ndarray
        The first time series data, assumed to be a 1D array of length n.
    y : np.ndarray
        The second time series data, assumed to be a 1D array of length n.

    Returns
    -------
    float
        The cross-correlation coefficient.
    """
    # Compute the mean and standard deviation of both time series
    mean_x = np.mean(x)
    mean_y = np.mean(y)
    std_x = np.std(x)
    std_y = np.std(y)

    # Compute the covariance and the correlation coefficient
    covariance = np.mean((x - mean_x) * (y - mean_y))
    correlation = covariance / (std_x * std_y)

    return correlation

def expert_stats(observed_x, observed_y, lags=[2,5]):
    """Computes fixed size statistics for an observed population trajectory

    Parameters
    ----------
    observed_x : np.ndarray with shape (num_observations, )
    observed_y : np.ndarray with shape (num_observations, )

    Returns
    -------
    dictionary with the following keys and values
    means      : np.ndarray with shape (2,)
    log_vars   : np.ndarray with shape (2,)
    auto_corrs : np.ndarray with shape (2*num_lags,)
        auto-correlation of each timeseries at lags 0.2 and 0.4 time units
    cross_corr : np.ndarray with shape (1,)
        the cross-correlation between the two time series
    period     : np.ndarray with shape (1,)
    """
    means = np.array([observed_x.mean(), observed_y.mean()])
    log_vars = np.log(np.array([observed_x.var(), observed_y.var()]))
    auto_corrs = np.array([
        autocorr(observed_x,lags),
        autocorr(observed_y,lags),
    ]).flatten()
    cross_corr = crosscorr(observed_x, observed_y)
    T = period(observed_x)
    
    return dict(
        means=means,
        log_vars=log_vars,
        auto_corrs=auto_corrs,
        cross_corr=cross_corr,
        period=T,
    )

# %%
expert_simulator = bf.make_simulator(
    [priors, ecology_model, observation_model, expert_stats]
)

# %%
samples_with_expert_stats = simulator.sample(3)
keras.tree.map_structure(keras.ops.shape, samples_with_expert_stats)
# Out:
# {'alpha': (3, 1),
#  'beta': (3, 1),
#  'gamma': (3, 1),
#  'delta': (3, 1),
#  'x': (3, 100),
#  'y': (3, 100),
#  't': (3, 100),
#  'observed_x': (3, 10),
#  'observed_y': (3, 10),
#  'observed_t': (3, 10)}

# %%
expert_adapter = (
    bf.adapters.Adapter()

    # convert from numpy's default float64 to deep learning friendly float32
    .convert_dtype("float64", "float32")

    # drop unobserved full trajectories and raw observations (optional)
    .drop(["x", "y", "t", "observed_x", "observed_y", "observed_t"])

    # rename the variables to match the required approximator inputs
    .concatenate(["alpha", "beta", "gamma", "delta"], into="inference_variables")
    .concatenate(["means", "log_vars", "auto_corrs", "cross_corr", "period"], into="inference_conditions")

)

# %%
expert_adapter
# Out:
# Adapter([0: ConvertDType -> 1: Drop(['x', 'y', 't', 'observed_x', 'observed_y', 'observed_t']) -> 2: Concatenate(['alpha', 'beta', 'gamma', 'delta'] -> 'inference_variables') -> 3: Concatenate(['means', 'log_vars', 'auto_corrs', 'cross_corr', 'period'] -> 'inference_conditions')])

# %%
quantile_levels = np.linspace(0.1, 0.9, 5)

# %%
point_inference_network = bf.networks.PointInferenceNetwork(
    scores=dict(
        mean=bf.scores.MeanScore(),
        quantiles=bf.scores.QuantileScore(quantile_levels)
    )
)

# %%
workflow = bf.BasicWorkflow(
    simulator=expert_simulator,
    adapter=expert_adapter,
    inference_network=point_inference_network
)

# %%
history = workflow.fit_online(
    epochs=50,
    num_batches_per_epoch=200,
    batch_size=32,
)
# Out:
# INFO:bayesflow:Fitting on dataset instance of OnlineDataset.
# INFO:bayesflow:Building on a test batch.
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3377 - mean/inference_mean: 0.4203 - quantiles/inference_quantiles: 0.2552
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.2984 - mean/inference_mean: 0.3716 - quantiles/inference_quantiles: 0.2252
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.2732 - mean/inference_mean: 0.3658 - quantiles/inference_quantiles: 0.1806
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1771 - mean/inference_mean: 0.2085 - quantiles/inference_quantiles: 0.1457
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1988 - mean/inference_mean: 0.2357 - quantiles/inference_quantiles: 0.1618
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1678 - mean/inference_mean: 0.1989 - quantiles/inference_quantiles: 0.1366
# Epoch 7/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1552 - mean/inference_mean: 0.1819 - quantiles/inference_quantiles: 0.1285
# Epoch 8/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1861 - mean/inference_mean: 0.2246 - quantiles/inference_quantiles: 0.1476
# Epoch 9/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1323 - mean/inference_mean: 0.1511 - quantiles/inference_quantiles: 0.1135
# Epoch 10/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1711 - mean/inference_mean: 0.2109 - quantiles/inference_quantiles: 0.1313
# Epoch 11/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1768 - mean/inference_mean: 0.2250 - quantiles/inference_quantiles: 0.1286
# Epoch 12/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1292 - mean/inference_mean: 0.1511 - quantiles/inference_quantiles: 0.1073
# Epoch 13/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.2090 - mean/inference_mean: 0.2727 - quantiles/inference_quantiles: 0.1452
# Epoch 14/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.2529 - mean/inference_mean: 0.3415 - quantiles/inference_quantiles: 0.1644
# Epoch 15/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1373 - mean/inference_mean: 0.1535 - quantiles/inference_quantiles: 0.1211
# Epoch 16/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1691 - mean/inference_mean: 0.2160 - quantiles/inference_quantiles: 0.1223
# Epoch 17/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1260 - mean/inference_mean: 0.1531 - quantiles/inference_quantiles: 0.0990
# Epoch 18/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1738 - mean/inference_mean: 0.2149 - quantiles/inference_quantiles: 0.1327
# Epoch 19/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1891 - mean/inference_mean: 0.2381 - quantiles/inference_quantiles: 0.1401
# Epoch 20/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1687 - mean/inference_mean: 0.2072 - quantiles/inference_quantiles: 0.1301
# Epoch 21/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1556 - mean/inference_mean: 0.1909 - quantiles/inference_quantiles: 0.1203
# Epoch 22/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1402 - mean/inference_mean: 0.1630 - quantiles/inference_quantiles: 0.1174
# Epoch 23/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1435 - mean/inference_mean: 0.1758 - quantiles/inference_quantiles: 0.1112
# Epoch 24/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1135 - mean/inference_mean: 0.1279 - quantiles/inference_quantiles: 0.0990
# Epoch 25/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1732 - mean/inference_mean: 0.2169 - quantiles/inference_quantiles: 0.1296
# Epoch 26/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1103 - mean/inference_mean: 0.1182 - quantiles/inference_quantiles: 0.1024
# Epoch 27/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1239 - mean/inference_mean: 0.1422 - quantiles/inference_quantiles: 0.1056
# Epoch 28/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1593 - mean/inference_mean: 0.1940 - quantiles/inference_quantiles: 0.1247
# Epoch 29/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1463 - mean/inference_mean: 0.1746 - quantiles/inference_quantiles: 0.1179
# Epoch 30/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1461 - mean/inference_mean: 0.1719 - quantiles/inference_quantiles: 0.1204
# Epoch 31/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1363 - mean/inference_mean: 0.1672 - quantiles/inference_quantiles: 0.1054
# Epoch 32/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1325 - mean/inference_mean: 0.1519 - quantiles/inference_quantiles: 0.1131
# Epoch 33/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1225 - mean/inference_mean: 0.1407 - quantiles/inference_quantiles: 0.1044
# Epoch 34/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1460 - mean/inference_mean: 0.1754 - quantiles/inference_quantiles: 0.1165
# Epoch 35/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1203 - mean/inference_mean: 0.1330 - quantiles/inference_quantiles: 0.1075
# Epoch 36/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0790 - mean/inference_mean: 0.0789 - quantiles/inference_quantiles: 0.0790
# Epoch 37/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1257 - mean/inference_mean: 0.1458 - quantiles/inference_quantiles: 0.1055
# Epoch 38/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1509 - mean/inference_mean: 0.1861 - quantiles/inference_quantiles: 0.1156
# Epoch 39/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1530 - mean/inference_mean: 0.1861 - quantiles/inference_quantiles: 0.1200
# Epoch 40/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1241 - mean/inference_mean: 0.1420 - quantiles/inference_quantiles: 0.1063
# Epoch 41/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1583 - mean/inference_mean: 0.1913 - quantiles/inference_quantiles: 0.1253
# Epoch 42/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1383 - mean/inference_mean: 0.1625 - quantiles/inference_quantiles: 0.1141
# Epoch 43/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1491 - mean/inference_mean: 0.1850 - quantiles/inference_quantiles: 0.1132
# Epoch 44/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1065 - mean/inference_mean: 0.1185 - quantiles/inference_quantiles: 0.0945
# Epoch 45/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1613 - mean/inference_mean: 0.2009 - quantiles/inference_quantiles: 0.1217
# Epoch 46/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1718 - mean/inference_mean: 0.2106 - quantiles/inference_quantiles: 0.1329
# Epoch 47/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1146 - mean/inference_mean: 0.1302 - quantiles/inference_quantiles: 0.0991
# Epoch 48/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.0977 - mean/inference_mean: 0.1041 - quantiles/inference_quantiles: 0.0913
# Epoch 49/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1633 - mean/inference_mean: 0.2012 - quantiles/inference_quantiles: 0.1255
# Epoch 50/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 0.1262 - mean/inference_mean: 0.1463 - quantiles/inference_quantiles: 0.1060

# %%
f = bf.diagnostics.loss(history)

# %%
validation_data = expert_simulator.sample(300)
variable_names = [r"$\alpha$", r"$\beta$", r"$\gamma$", r"$\delta$"]

# %%
# Set the number of posterior draws you want to get
point_estimates = workflow.estimate(conditions=validation_data)

# %%
keras.tree.map_structure(keras.ops.shape, point_estimates)
# Out:
# {'alpha': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'beta': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'gamma': {'mean': (300, 1), 'quantiles': (300, 5, 1)},
#  'delta': {'mean': (300, 1), 'quantiles': (300, 5, 1)}}

# %%
marker_mapping = dict(quantiles="_", mean="*")

# %%
point_recovery = bf.diagnostics.plots.recovery_from_estimates(
    estimates=point_estimates, 
    targets=validation_data, 
    variable_names=variable_names,
    marker_mapping=marker_mapping
)

# For saving only
# point_recovery.savefig("../figures/point_recovery.pdf")

# %%
f = bf.diagnostics.plots.calibration_ecdf_from_quantiles(
    estimates=point_estimates, 
    targets=validation_data,
    quantile_levels=quantile_levels,
    difference=False,
    variable_names=variable_names,
)
# For saving only
# f.savefig("../figures/point_ecdf.pdf")

# %%
posterior_bounds_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,[0,-1]], {k:v["quantiles"] for k,v in point_estimates.items()}
)

# %%
from scipy.stats import norm

std_normal_quantiles = norm.ppf(quantile_levels[[0,-1]])
std_normal_quantiles
# Out:
# array([-1.28155157,  1.28155157])

# %%
# calculate interpolation value for mean and standard deviation
alpha = std_normal_quantiles[0] / (std_normal_quantiles[0] - std_normal_quantiles[1])
beta = (std_normal_quantiles[0] - 1) / (std_normal_quantiles[0] - std_normal_quantiles[1])

# %%
posterior_means_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,0] * (1-alpha) + v[:,1] * alpha, posterior_bounds_from_quantiles
)
posterior_stds_from_quantiles = keras.tree.map_structure(
    lambda v: v[:,0] * (alpha-beta) + v[:,1] * (beta-alpha), posterior_bounds_from_quantiles
)

# %%
num_samples = 300

# sample from normal distribution consistent with quantile estimates
posterior_draws_from_quantiles = keras.tree.map_structure(
    lambda v: rng.normal(
    loc=v[:,0] * (1-alpha) + v[:,1] * alpha, 
    scale=v[:,0] * (alpha-beta) + v[:,1] * (beta-alpha),
    size=(300, num_samples))[..., None], posterior_bounds_from_quantiles
)

# %%
dataset_id = 1
list_of_resimulations = []
for sample_id in range(num_samples):
    one_post_sample = take_posterior_sample(posterior_draws_from_quantiles, dataset_id, sample_id)
    list_of_resimulations.append(ecology_model(t_span=[0,20], **one_post_sample))
resimulation_samples = bf.utils.tree_stack(list_of_resimulations, axis=0)

observations = take_dataset(validation_data, dataset_id)

f = plot_trajectories(
    resimulation_samples, ["x", "y"], ["Prey", "Predator"], 
    observations=observations, 
    legend_ncol=4, 
    figsize=(12.5, 5)
    )

# For saving only
# f.savefig("../figures/point_trajectories.pdf")
